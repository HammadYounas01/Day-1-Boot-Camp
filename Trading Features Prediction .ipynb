# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
rcParams['figure.figsize']=10,6

# %%
df=pd.read_csv('Trading-features.csv')

# %%
df
# Out:
#             id  last_price                  created_at        f1     f2    f3  \
# 0     55466910     43138.2  2023-12-27 12:47:41.916971  0.000463  15139 -43.1
# 1     55466909     43138.2  2023-12-27 12:47:40.693372  0.000463  15140 -43.1
# 2     55466908     43138.2  2023-12-27 12:47:39.968797  0.000463  15141 -37.4
# 3     55466907     43138.2  2023-12-27 12:47:38.919784  0.000463  15142 -37.4
# 4     55466906     43132.6  2023-12-27 12:47:37.881533  0.000463  15143 -39.6
# ...        ...         ...                         ...       ...    ...   ...
# 9995  55456903     42753.6  2023-12-27 10:00:09.874616  0.000414  25191 -29.5
# 9996  55456902     42753.6  2023-12-27 10:00:08.803069  0.000414  25192 -29.5
# 9997  55456901     42753.6  2023-12-27 10:00:07.957261  0.000414  25193 -36.7
# 9998  55456900     42753.7  2023-12-27 10:00:06.730827  0.000414  25194 -36.7
# 9999  55456899     42765.6  2023-12-27 10:00:05.707968  0.000414  25196 -36.7
#
#         f4    f5    f6    f7  ...   f152   f153   f154   f155   f156   f157  \
# 0     43.0  -0.1  -4.8  -5.1  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2
# 1     43.0  -0.1  -4.7  -5.1  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2
# 2     43.0   5.6  -1.9  -0.6  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2
# 3     37.4   0.0  -3.7  -6.2  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2
# 4     36.5  -3.1  -3.7  -9.4  ...  689.6 -129.4  689.6 -129.4 -129.4  689.6
# ...    ...   ...   ...   ...  ...    ...    ...    ...    ...    ...    ...
# 9995  29.4  -0.1   3.5   9.6  ...  440.2  -41.3  440.2  -41.3  -41.3  440.2
# 9996  29.4  -0.1   3.4   9.6  ...  440.2  -41.3  440.2  -41.3  -41.3  440.2
# 9997  36.6  -0.1   3.7   9.7  ...  440.2  -41.3  440.2  -41.3  -41.3  440.2
# 9998  48.5  11.8  22.6  21.6  ...  440.3  -41.2  440.3  -41.2  -41.2  440.3
# 9999  48.5  11.8  22.7  19.8  ...  452.2  -29.3  452.2  -29.3  -29.3  452.2
#
#        f158   f159   f160   f161
# 0     695.2 -123.8 -123.8  695.2
# 1     695.2 -123.8 -123.8  695.2
# 2     695.2 -123.8 -123.8  695.2
# 3     695.2 -123.8 -123.8  695.2
# 4     689.6 -129.4 -129.4  689.6
# ...     ...    ...    ...    ...
# 9995  440.2  -41.3  -41.3  440.2
# 9996  440.2  -41.3  -41.3  440.2
# 9997  440.2  -41.3  -41.3  440.2
# 9998  440.3  -41.2  -41.2  440.3
# 9999  452.2  -29.3  -29.3  452.2
#
# [10000 rows x 164 columns]

# %%
df.describe()
# Out:
#                  id    last_price            f1           f2            f3  \
# count  1.000000e+04  10000.000000  10000.000000  10000.00000  10000.000000
# mean   5.546190e+07  42938.580560      0.000414  20149.80990    -40.236010
# std    2.890879e+03    205.486455      0.000018   2897.95985      7.212493
# min    5.545690e+07  42659.500000      0.000397  15139.00000    -57.800000
# 25%    5.545940e+07  42747.400000      0.000400  17642.00000    -46.000000
# 50%    5.546190e+07  42835.850000      0.000408  20146.00000    -38.200000
# 75%    5.546441e+07  43145.225000      0.000417  22652.25000    -34.500000
# max    5.546691e+07  43262.000000      0.000463  25196.00000    -22.100000
#
#                  f4            f5            f6            f7           f8  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.00000
# mean      42.252370      2.016360      0.523120      1.103560      2.29049
# std        9.346334      5.339766     12.883223     17.590602     24.03562
# min       15.000000    -27.100000    -51.900000    -59.900000    -75.70000
# 25%       35.700000      0.000000     -5.600000     -8.300000    -11.00000
# 50%       40.500000      0.800000      0.000000      0.100000      0.40000
# 75%       48.500000      3.900000      5.725000      8.800000     12.20000
# max      124.200000     85.300000    135.000000    135.700000    179.00000
#
#        ...          f152          f153          f154          f155  \
# count  ...  10000.000000  10000.000000  10000.000000  10000.000000
# mean   ...    533.201440    -74.606490    533.201440    -74.606490
# std    ...    177.929894     46.736091    177.929894     46.736091
# min    ...    301.200000   -196.300000    301.200000   -196.300000
# 25%    ...    359.100000   -104.825000    359.100000   -104.825000
# 50%    ...    450.800000    -61.200000    450.800000    -61.200000
# 75%    ...    712.325000    -37.700000    712.325000    -37.700000
# max    ...    831.300000     49.400000    831.300000     49.400000
#
#                f156          f157          f158          f159          f160  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean     -74.606490    533.201440    533.201440    -74.606490    -74.606490
# std       46.736091    177.929894    177.929894     46.736091     46.736091
# min     -196.300000    301.200000    301.200000   -196.300000   -196.300000
# 25%     -104.825000    359.100000    359.100000   -104.825000   -104.825000
# 50%      -61.200000    450.800000    450.800000    -61.200000    -61.200000
# 75%      -37.700000    712.325000    712.325000    -37.700000    -37.700000
# max       49.400000    831.300000    831.300000     49.400000     49.400000
#
#                f161
# count  10000.000000
# mean     533.201440
# std      177.929894
# min      301.200000
# 25%      359.100000
# 50%      450.800000
# 75%      712.325000
# max      831.300000
#
# [8 rows x 163 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Columns: 164 entries, id to f161
# dtypes: float64(136), int64(27), object(1)
# memory usage: 12.5+ MB

# %%
df.isnull().sum()
# Out:
# id            0
# last_price    0
# created_at    0
# f1            0
# f2            0
#              ..
# f157          0
# f158          0
# f159          0
# f160          0
# f161          0
# Length: 164, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'last_price', 'created_at', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6',
#        'f7',
#        ...
#        'f152', 'f153', 'f154', 'f155', 'f156', 'f157', 'f158', 'f159', 'f160',
#        'f161'],
#       dtype='object', length=164)

# %% [markdown]
# ## Converting Dates column to datetime format

# %%
df['created_at']
# Out:
# 0       2023-12-27 12:47:41.916971
# 1       2023-12-27 12:47:40.693372
# 2       2023-12-27 12:47:39.968797
# 3       2023-12-27 12:47:38.919784
# 4       2023-12-27 12:47:37.881533
#                    ...
# 9995    2023-12-27 10:00:09.874616
# 9996    2023-12-27 10:00:08.803069
# 9997    2023-12-27 10:00:07.957261
# 9998    2023-12-27 10:00:06.730827
# 9999    2023-12-27 10:00:05.707968
# Name: created_at, Length: 10000, dtype: object

# %%
df['created_at']=pd.to_datetime(df['created_at'])

# %%
df['date']=df['created_at'].dt.strftime('%Y-%m-%d')

# %%
df['created_at']=df['created_at'].dt.strftime('%H:%M:%S')

# %%
df.set_index('created_at', inplace=True)

# %%
df
# Out:
#                   id  last_price        f1     f2    f3    f4    f5    f6  \
# created_at
# 12:47:41    55466910     43138.2  0.000463  15139 -43.1  43.0  -0.1  -4.8
# 12:47:40    55466909     43138.2  0.000463  15140 -43.1  43.0  -0.1  -4.7
# 12:47:39    55466908     43138.2  0.000463  15141 -37.4  43.0   5.6  -1.9
# 12:47:38    55466907     43138.2  0.000463  15142 -37.4  37.4   0.0  -3.7
# 12:47:37    55466906     43132.6  0.000463  15143 -39.6  36.5  -3.1  -3.7
# ...              ...         ...       ...    ...   ...   ...   ...   ...
# 10:00:09    55456903     42753.6  0.000414  25191 -29.5  29.4  -0.1   3.5
# 10:00:08    55456902     42753.6  0.000414  25192 -29.5  29.4  -0.1   3.4
# 10:00:07    55456901     42753.6  0.000414  25193 -36.7  36.6  -0.1   3.7
# 10:00:06    55456900     42753.7  0.000414  25194 -36.7  48.5  11.8  22.6
# 10:00:05    55456899     42765.6  0.000414  25196 -36.7  48.5  11.8  22.7
#
#               f7    f8  ...   f153   f154   f155   f156   f157   f158   f159  \
# created_at              ...
# 12:47:41    -5.1  -4.3  ... -123.8  695.2 -123.8 -123.8  695.2  695.2 -123.8
# 12:47:40    -5.1  -2.4  ... -123.8  695.2 -123.8 -123.8  695.2  695.2 -123.8
# 12:47:39    -0.6  -2.4  ... -123.8  695.2 -123.8 -123.8  695.2  695.2 -123.8
# 12:47:38    -6.2 -10.2  ... -123.8  695.2 -123.8 -123.8  695.2  695.2 -123.8
# 12:47:37    -9.4 -10.2  ... -129.4  689.6 -129.4 -129.4  689.6  689.6 -129.4
# ...          ...   ...  ...    ...    ...    ...    ...    ...    ...    ...
# 10:00:09     9.6   9.7  ...  -41.3  440.2  -41.3  -41.3  440.2  440.2  -41.3
# 10:00:08     9.6   9.7  ...  -41.3  440.2  -41.3  -41.3  440.2  440.2  -41.3
# 10:00:07     9.7  12.6  ...  -41.3  440.2  -41.3  -41.3  440.2  440.2  -41.3
# 10:00:06    21.6  23.7  ...  -41.2  440.3  -41.2  -41.2  440.3  440.3  -41.2
# 10:00:05    19.8  21.7  ...  -29.3  452.2  -29.3  -29.3  452.2  452.2  -29.3
#
#              f160   f161        date
# created_at
# 12:47:41   -123.8  695.2  2023-12-27
# 12:47:40   -123.8  695.2  2023-12-27
# 12:47:39   -123.8  695.2  2023-12-27
# 12:47:38   -123.8  695.2  2023-12-27
# 12:47:37   -129.4  689.6  2023-12-27
# ...           ...    ...         ...
# 10:00:09    -41.3  440.2  2023-12-27
# 10:00:08    -41.3  440.2  2023-12-27
# 10:00:07    -41.3  440.2  2023-12-27
# 10:00:06    -41.2  440.3  2023-12-27
# 10:00:05    -29.3  452.2  2023-12-27
#
# [10000 rows x 164 columns]

# %%
df['date'].min()
# Out:
# '2023-12-27'

# %%
rolmean=df['last_price'].rolling(window=30).mean()
rolstd=df['last_price'].rolling(window=30).std()

# %%
rolmean
# Out:
# created_at
# 12:47:41             NaN
# 12:47:40             NaN
# 12:47:39             NaN
# 12:47:38             NaN
# 12:47:37             NaN
#                 ...
# 10:00:09    42762.200000
# 10:00:08    42762.280000
# 10:00:07    42762.186667
# 10:00:06    42761.966667
# 10:00:05    42762.140000
# Name: last_price, Length: 10000, dtype: float64

# %%
plt.figure(figsize=(16, 7))
fig=plt.figure(1)
ax1=fig.add_subplot(111)
orig=plt.plot(df['last_price'][:300], color='blue', label='Orignal')
rmean=plt.plot(rolmean, color='red', label='Mean')
rstd=plt.plot(rolstd, color='black', label='Std')
ax1.plot()
# Out:
# []

# %% [markdown]
# ## Visualizing stock price over a time

# %%
plt.figure(figsize=(9, 8))
plt.plot(df.index,df['last_price'])
plt.title('Stock Prices Over Time')
plt.xlabel('Time')
plt.ylabel('Last Price')
plt.xticks(rotation=45)
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse

# %%
plt.rcParams.update({'figure.figsize':(16,8)})
plt.plot(df['last_price'][:100])

# %%
mul_result=seasonal_decompose(df['last_price'][:100],model='multiplicative',period=1)

# %%
ad_result=seasonal_decompose(df['last_price'][:100],model='additive',period=1)

# %%
plt.rcParams.update({'figure.figsize':(8,8)})
mul_result.plot().suptitle('\nMultiplicative Decompose',fontsize=12)
# Out:
# Text(0.5, 0.98, '\nMultiplicative Decompose')

# %%
plt.rcParams.update({'figure.figsize':(8,8)})
ad_result.plot().suptitle('\nAdditive Decompose',fontsize=12)
# Out:
# Text(0.5, 0.98, '\nAdditive Decompose')

# %%
from statsmodels.tsa.stattools import adfuller
add_re=adfuller(df['last_price'],autolag='AIC')
print('adf value: ',add_re[0])
print('pvalue: ',add_re[1])
# Out:
# adf value:  -0.81803747115963
# pvalue:  0.8137661953368684

# %%
df
# Out:
#                   id  last_price        f1     f2    f3    f4    f5    f6  \
# created_at
# 12:47:41    55466910     43138.2  0.000463  15139 -43.1  43.0  -0.1  -4.8
# 12:47:40    55466909     43138.2  0.000463  15140 -43.1  43.0  -0.1  -4.7
# 12:47:39    55466908     43138.2  0.000463  15141 -37.4  43.0   5.6  -1.9
# 12:47:38    55466907     43138.2  0.000463  15142 -37.4  37.4   0.0  -3.7
# 12:47:37    55466906     43132.6  0.000463  15143 -39.6  36.5  -3.1  -3.7
# ...              ...         ...       ...    ...   ...   ...   ...   ...
# 10:00:09    55456903     42753.6  0.000414  25191 -29.5  29.4  -0.1   3.5
# 10:00:08    55456902     42753.6  0.000414  25192 -29.5  29.4  -0.1   3.4
# 10:00:07    55456901     42753.6  0.000414  25193 -36.7  36.6  -0.1   3.7
# 10:00:06    55456900     42753.7  0.000414  25194 -36.7  48.5  11.8  22.6
# 10:00:05    55456899     42765.6  0.000414  25196 -36.7  48.5  11.8  22.7
#
#               f7    f8  ...   f153   f154   f155   f156   f157   f158   f159  \
# created_at              ...
# 12:47:41    -5.1  -4.3  ... -123.8  695.2 -123.8 -123.8  695.2  695.2 -123.8
# 12:47:40    -5.1  -2.4  ... -123.8  695.2 -123.8 -123.8  695.2  695.2 -123.8
# 12:47:39    -0.6  -2.4  ... -123.8  695.2 -123.8 -123.8  695.2  695.2 -123.8
# 12:47:38    -6.2 -10.2  ... -123.8  695.2 -123.8 -123.8  695.2  695.2 -123.8
# 12:47:37    -9.4 -10.2  ... -129.4  689.6 -129.4 -129.4  689.6  689.6 -129.4
# ...          ...   ...  ...    ...    ...    ...    ...    ...    ...    ...
# 10:00:09     9.6   9.7  ...  -41.3  440.2  -41.3  -41.3  440.2  440.2  -41.3
# 10:00:08     9.6   9.7  ...  -41.3  440.2  -41.3  -41.3  440.2  440.2  -41.3
# 10:00:07     9.7  12.6  ...  -41.3  440.2  -41.3  -41.3  440.2  440.2  -41.3
# 10:00:06    21.6  23.7  ...  -41.2  440.3  -41.2  -41.2  440.3  440.3  -41.2
# 10:00:05    19.8  21.7  ...  -29.3  452.2  -29.3  -29.3  452.2  452.2  -29.3
#
#              f160   f161        date
# created_at
# 12:47:41   -123.8  695.2  2023-12-27
# 12:47:40   -123.8  695.2  2023-12-27
# 12:47:39   -123.8  695.2  2023-12-27
# 12:47:38   -123.8  695.2  2023-12-27
# 12:47:37   -129.4  689.6  2023-12-27
# ...           ...    ...         ...
# 10:00:09    -41.3  440.2  2023-12-27
# 10:00:08    -41.3  440.2  2023-12-27
# 10:00:07    -41.3  440.2  2023-12-27
# 10:00:06    -41.2  440.3  2023-12-27
# 10:00:05    -29.3  452.2  2023-12-27
#
# [10000 rows x 164 columns]

# %%
df.shape
# Out:
# (10000, 164)

# %%
df.drop('date', axis=1,inplace=True)

# %%
df
# Out:
#                   id  last_price        f1     f2    f3    f4    f5    f6  \
# created_at
# 12:47:41    55466910     43138.2  0.000463  15139 -43.1  43.0  -0.1  -4.8
# 12:47:40    55466909     43138.2  0.000463  15140 -43.1  43.0  -0.1  -4.7
# 12:47:39    55466908     43138.2  0.000463  15141 -37.4  43.0   5.6  -1.9
# 12:47:38    55466907     43138.2  0.000463  15142 -37.4  37.4   0.0  -3.7
# 12:47:37    55466906     43132.6  0.000463  15143 -39.6  36.5  -3.1  -3.7
# ...              ...         ...       ...    ...   ...   ...   ...   ...
# 10:00:09    55456903     42753.6  0.000414  25191 -29.5  29.4  -0.1   3.5
# 10:00:08    55456902     42753.6  0.000414  25192 -29.5  29.4  -0.1   3.4
# 10:00:07    55456901     42753.6  0.000414  25193 -36.7  36.6  -0.1   3.7
# 10:00:06    55456900     42753.7  0.000414  25194 -36.7  48.5  11.8  22.6
# 10:00:05    55456899     42765.6  0.000414  25196 -36.7  48.5  11.8  22.7
#
#               f7    f8  ...   f152   f153   f154   f155   f156   f157   f158  \
# created_at              ...
# 12:47:41    -5.1  -4.3  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2  695.2
# 12:47:40    -5.1  -2.4  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2  695.2
# 12:47:39    -0.6  -2.4  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2  695.2
# 12:47:38    -6.2 -10.2  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2  695.2
# 12:47:37    -9.4 -10.2  ...  689.6 -129.4  689.6 -129.4 -129.4  689.6  689.6
# ...          ...   ...  ...    ...    ...    ...    ...    ...    ...    ...
# 10:00:09     9.6   9.7  ...  440.2  -41.3  440.2  -41.3  -41.3  440.2  440.2
# 10:00:08     9.6   9.7  ...  440.2  -41.3  440.2  -41.3  -41.3  440.2  440.2
# 10:00:07     9.7  12.6  ...  440.2  -41.3  440.2  -41.3  -41.3  440.2  440.2
# 10:00:06    21.6  23.7  ...  440.3  -41.2  440.3  -41.2  -41.2  440.3  440.3
# 10:00:05    19.8  21.7  ...  452.2  -29.3  452.2  -29.3  -29.3  452.2  452.2
#
#              f159   f160   f161
# created_at
# 12:47:41   -123.8 -123.8  695.2
# 12:47:40   -123.8 -123.8  695.2
# 12:47:39   -123.8 -123.8  695.2
# 12:47:38   -123.8 -123.8  695.2
# 12:47:37   -129.4 -129.4  689.6
# ...           ...    ...    ...
# 10:00:09    -41.3  -41.3  440.2
# 10:00:08    -41.3  -41.3  440.2
# 10:00:07    -41.3  -41.3  440.2
# 10:00:06    -41.2  -41.2  440.3
# 10:00:05    -29.3  -29.3  452.2
#
# [10000 rows x 163 columns]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#             id  last_price        f1     f2    f3    f4    f5    f6    f7  \
# 0     55466910     43138.2  0.000463  15139 -43.1  43.0  -0.1  -4.8  -5.1
# 1     55466909     43138.2  0.000463  15140 -43.1  43.0  -0.1  -4.7  -5.1
# 2     55466908     43138.2  0.000463  15141 -37.4  43.0   5.6  -1.9  -0.6
# 3     55466907     43138.2  0.000463  15142 -37.4  37.4   0.0  -3.7  -6.2
# 4     55466906     43132.6  0.000463  15143 -39.6  36.5  -3.1  -3.7  -9.4
# ...        ...         ...       ...    ...   ...   ...   ...   ...   ...
# 9995  55456903     42753.6  0.000414  25191 -29.5  29.4  -0.1   3.5   9.6
# 9996  55456902     42753.6  0.000414  25192 -29.5  29.4  -0.1   3.4   9.6
# 9997  55456901     42753.6  0.000414  25193 -36.7  36.6  -0.1   3.7   9.7
# 9998  55456900     42753.7  0.000414  25194 -36.7  48.5  11.8  22.6  21.6
# 9999  55456899     42765.6  0.000414  25196 -36.7  48.5  11.8  22.7  19.8
#
#         f8  ...   f152   f153   f154   f155   f156   f157   f158   f159  \
# 0     -4.3  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2  695.2 -123.8
# 1     -2.4  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2  695.2 -123.8
# 2     -2.4  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2  695.2 -123.8
# 3    -10.2  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2  695.2 -123.8
# 4    -10.2  ...  689.6 -129.4  689.6 -129.4 -129.4  689.6  689.6 -129.4
# ...    ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 9995   9.7  ...  440.2  -41.3  440.2  -41.3  -41.3  440.2  440.2  -41.3
# 9996   9.7  ...  440.2  -41.3  440.2  -41.3  -41.3  440.2  440.2  -41.3
# 9997  12.6  ...  440.2  -41.3  440.2  -41.3  -41.3  440.2  440.2  -41.3
# 9998  23.7  ...  440.3  -41.2  440.3  -41.2  -41.2  440.3  440.3  -41.2
# 9999  21.7  ...  452.2  -29.3  452.2  -29.3  -29.3  452.2  452.2  -29.3
#
#        f160   f161
# 0    -123.8  695.2
# 1    -123.8  695.2
# 2    -123.8  695.2
# 3    -123.8  695.2
# 4    -129.4  689.6
# ...     ...    ...
# 9995  -41.3  440.2
# 9996  -41.3  440.2
# 9997  -41.3  440.2
# 9998  -41.2  440.3
# 9999  -29.3  452.2
#
# [10000 rows x 163 columns]

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#             id  last_price        f1     f2    f3    f4    f5    f6    f7  \
# 0     55466910     43138.2  0.000463  15139 -43.1  43.0  -0.1  -4.8  -5.1
# 1     55466909     43138.2  0.000463  15140 -43.1  43.0  -0.1  -4.7  -5.1
# 2     55466908     43138.2  0.000463  15141 -37.4  43.0   5.6  -1.9  -0.6
# 3     55466907     43138.2  0.000463  15142 -37.4  37.4   0.0  -3.7  -6.2
# 4     55466906     43132.6  0.000463  15143 -39.6  36.5  -3.1  -3.7  -9.4
# ...        ...         ...       ...    ...   ...   ...   ...   ...   ...
# 9995  55456903     42753.6  0.000414  25191 -29.5  29.4  -0.1   3.5   9.6
# 9996  55456902     42753.6  0.000414  25192 -29.5  29.4  -0.1   3.4   9.6
# 9997  55456901     42753.6  0.000414  25193 -36.7  36.6  -0.1   3.7   9.7
# 9998  55456900     42753.7  0.000414  25194 -36.7  48.5  11.8  22.6  21.6
# 9999  55456899     42765.6  0.000414  25196 -36.7  48.5  11.8  22.7  19.8
#
#         f8  ...   f152   f153   f154   f155   f156   f157   f158   f159  \
# 0     -4.3  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2  695.2 -123.8
# 1     -2.4  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2  695.2 -123.8
# 2     -2.4  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2  695.2 -123.8
# 3    -10.2  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2  695.2 -123.8
# 4    -10.2  ...  689.6 -129.4  689.6 -129.4 -129.4  689.6  689.6 -129.4
# ...    ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 9995   9.7  ...  440.2  -41.3  440.2  -41.3  -41.3  440.2  440.2  -41.3
# 9996   9.7  ...  440.2  -41.3  440.2  -41.3  -41.3  440.2  440.2  -41.3
# 9997  12.6  ...  440.2  -41.3  440.2  -41.3  -41.3  440.2  440.2  -41.3
# 9998  23.7  ...  440.3  -41.2  440.3  -41.2  -41.2  440.3  440.3  -41.2
# 9999  21.7  ...  452.2  -29.3  452.2  -29.3  -29.3  452.2  452.2  -29.3
#
#        f160   f161
# 0    -123.8  695.2
# 1    -123.8  695.2
# 2    -123.8  695.2
# 3    -123.8  695.2
# 4    -129.4  689.6
# ...     ...    ...
# 9995  -41.3  440.2
# 9996  -41.3  440.2
# 9997  -41.3  440.2
# 9998  -41.2  440.3
# 9999  -29.3  452.2
#
# [9979 rows x 163 columns]

# %%
X=df.iloc[:,2:].values
X.shape
# Out:
# (9979, 161)

# %%
y=df.iloc[:,1:2].values

# %%
y
# Out:
# array([[43138.2],
#        [43138.2],
#        [43138.2],
#        ...,
#        [42753.6],
#        [42753.7],
#        [42765.6]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_squared_error

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 10)

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.9995781863908307

# %%
y_pred = model.predict(X_test)
np.set_printoptions(precision=2)
output=np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1)

# %%
output
# Out:
# array([[42763.48, 42753.7 ],
#        [43157.59, 43157.8 ],
#        [42754.92, 42752.9 ],
#        ...,
#        [43211.42, 43213.5 ],
#        [42752.72, 42767.1 ],
#        [42745.32, 42745.  ]])

# %%
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error (MAE): {mae}')
# Out:
# Mean Absolute Error (MAE): 3.1021149039561116

# %%
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error (MSE): {mse}')

# Optionally, you can also print the Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)
print(f'Root Mean Squared Error (RMSE): {rmse}')
# Out:
# Mean Squared Error (MSE): 17.589041886480665
# Root Mean Squared Error (RMSE): 4.19392917041772
